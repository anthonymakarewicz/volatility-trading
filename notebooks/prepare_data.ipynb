# %%
# %load_ext autoreload
# %autoreload 2

import warnings
from utility.data_processor_helpers import *
from config.paths import RAW_PATH, INTERMEDIATE_PATH
from pandas.tseries.offsets import BMonthEnd

warnings.filterwarnings(action="ignore")

# %%
option_path = "spx_options"
start_year = 2021
end_year = 2023

df = load_options(RAW_PATH / option_path, start_year=start_year, end_year=end_year)
df = clean_data(df)
df = reshape_options_long_to_wide(df)

output_file = INTERMEDIATE_PATH / f"full_{option_path}_{start_year}_{end_year}.parquet"
df.to_parquet(output_file, index=True)
# Out:
# Processing year: 2021
#   ➤ Extracting spx_eod_2021-n4uqkm.7z
# Reading tmp/spx_eod_202102.txt
# Reading tmp/spx_eod_202103.txt
# Reading tmp/spx_eod_202101.txt
# Reading tmp/spx_eod_202104.txt
# Reading tmp/spx_eod_202105.txt
# Reading tmp/spx_eod_202106.txt
#   ➤ Extracting spx_eod_2021q3-kgzold.7z
# Reading tmp/spx_eod_202108.txt
# Reading tmp/spx_eod_202109.txt
# Reading tmp/spx_eod_202107.txt
#   ➤ Extracting spx_eod_2021q4-r3h0dx.7z
# Reading tmp/spx_eod_202110.txt
# Reading tmp/spx_eod_202111.txt
# Reading tmp/spx_eod_202112.txt
# Processing year: 2022
#   ➤ Extracting spx_eod_2022q1-ff0r18.7z
# Reading tmp/spx_eod_202203.txt
# Reading tmp/spx_eod_202202.txt
# Reading tmp/spx_eod_202201.txt
#   ➤ Extracting spx_eod_2022q2-bxgzw0.7z
# Reading tmp/spx_eod_202205.txt
# Reading tmp/spx_eod_202204.txt
# Reading tmp/spx_eod_202206.txt
#   ➤ Extracting spx_eod_2022q3-1f2afi.7z
# Reading tmp/spx_eod_202209.txt
# Reading tmp/spx_eod_202208.txt
# Reading tmp/spx_eod_202207.txt
#   ➤ Extracting spx_eod_2022q4-dmme3k.7z
# Reading tmp/spx_eod_202211.txt
# Reading tmp/spx_eod_202210.txt
# Reading tmp/spx_eod_202212.txt
# Processing year: 2023
#   ➤ Extracting spx_eod_2023q1-cfph7w.7z
# Reading tmp/spx_eod_202301.txt
# Reading tmp/spx_eod_202303.txt
# Reading tmp/spx_eod_202302.txt
#   ➤ Extracting spx_eod_2023q2-kdxt36.7z
# Reading tmp/spx_eod_202306.txt
# Reading tmp/spx_eod_202305.txt
# Reading tmp/spx_eod_202304.txt
#   ➤ Extracting spx_eod_2023q3-w9b0jk.7z
# Reading tmp/spx_eod_202309.txt
# Reading tmp/spx_eod_202308.txt
# Reading tmp/spx_eod_202307.txt
#   ➤ Extracting spx_eod_2023q4-ai4uc9.7z
# Reading tmp/spx_eod_202312.txt
# Reading tmp/spx_eod_202311.txt
# Reading tmp/spx_eod_202310.txt
