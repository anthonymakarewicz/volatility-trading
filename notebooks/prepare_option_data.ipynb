# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from volatility_trading.options.io import prepare_option_panel
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
raw_root = "../data/raw/spx_options"
output_file = "../data/intermediate/full_spx_options_2021_2023.parquet"
start_year = 2019
end_year = 2020

parquet_path = prepare_option_panel(
    raw_root=raw_root,
    output_path=output_file,
    start_year=start_year,
    end_year=end_year,
    low_memory=False
)
df = pd.read_parquet(parquet_path)
# Out:
# Processing year: 2019
#   ➤ Extracting spx_eod_2019-chxexe.7z
# Reading ../data/raw/spx_options/2019/_tmp_extract/spx_eod_2019-chxexe/spx_eod_201909.txt
# Reading ../data/raw/spx_options/2019/_tmp_extract/spx_eod_2019-chxexe/spx_eod_201908.txt
# Reading ../data/raw/spx_options/2019/_tmp_extract/spx_eod_2019-chxexe/spx_eod_201905.txt
# Reading ../data/raw/spx_options/2019/_tmp_extract/spx_eod_2019-chxexe/spx_eod_201911.txt
# Reading ../data/raw/spx_options/2019/_tmp_extract/spx_eod_2019-chxexe/spx_eod_201910.txt
# Reading ../data/raw/spx_options/2019/_tmp_extract/spx_eod_2019-chxexe/spx_eod_201904.txt
# Reading ../data/raw/spx_options/2019/_tmp_extract/spx_eod_2019-chxexe/spx_eod_201912.txt
# Reading ../data/raw/spx_options/2019/_tmp_extract/spx_eod_2019-chxexe/spx_eod_201906.txt
# Reading ../data/raw/spx_options/2019/_tmp_extract/spx_eod_2019-chxexe/spx_eod_201907.txt
# Reading ../data/raw/spx_options/2019/_tmp_extract/spx_eod_2019-chxexe/spx_eod_201903.txt
# ...
