# %%
# %load_ext autoreload
# %autoreload 2

import warnings
from utility.data_processor_helpers import *
from config.paths import RAW_PATH, INTERMEDIATE_PATH
from pandas.tseries.offsets import BMonthEnd

warnings.filterwarnings(action="ignore")

# %%
option_path = "spx_options"
start_year = 2015
end_year = 2020

df = load_options(RAW_PATH / option_path, start_year=start_year, end_year=end_year)
df = clean_data(df)
df = reshape_options_long_to_wide(df)

output_file = INTERMEDIATE_PATH / f"full_{option_path}_{start_year}_{end_year}.parquet"
df.to_parquet(output_file, index=True)
# Out:
# Processing year: 2015
#   ➤ Extracting spx_eod_2015-amtjlk.7z
# Reading tmp/spx_eod_201809.txt
# Reading tmp/spx_eod_201808.txt
# Reading tmp/spx_eod_201501.txt
# Reading tmp/spx_eod_201502.txt
# Reading tmp/spx_eod_201503.txt
# Reading tmp/spx_eod_201507.txt
# Reading tmp/spx_eod_201506.txt
# Reading tmp/spx_eod_201512.txt
# Reading tmp/spx_eod_201504.txt
# Reading tmp/spx_eod_201510.txt
# Reading tmp/spx_eod_201511.txt
# Reading tmp/spx_eod_201505.txt
# Reading tmp/spx_eod_201508.txt
# Reading tmp/spx_eod_201509.txt
# Reading tmp/spx_eod_201812.txt
# Reading tmp/spx_eod_201806.txt
# Reading tmp/spx_eod_201807.txt
# Reading tmp/spx_eod_201805.txt
# Reading tmp/spx_eod_201811.txt
# Reading tmp/spx_eod_201810.txt
# Reading tmp/spx_eod_201804.txt
# Reading tmp/spx_eod_201801.txt
# Reading tmp/spx_eod_201803.txt
# Reading tmp/spx_eod_201802.txt
# Processing year: 2016
#   ➤ Extracting spx_eod_2016-rctzlw.7z
# Reading tmp/spx_eod_201601.txt
# Reading tmp/spx_eod_201603.txt
# Reading tmp/spx_eod_201602.txt
# Reading tmp/spx_eod_201606.txt
# Reading tmp/spx_eod_201612.txt
# Reading tmp/spx_eod_201607.txt
# Reading tmp/spx_eod_201611.txt
# Reading tmp/spx_eod_201605.txt
# Reading tmp/spx_eod_201604.txt
# Reading tmp/spx_eod_201610.txt
# Reading tmp/spx_eod_201609.txt
# Reading tmp/spx_eod_201608.txt
# Processing year: 2017
#   ➤ Extracting spx_eod_2017-xspity.7z
# Reading tmp/spx_eod_201703.txt
# Reading tmp/spx_eod_201702.txt
# Reading tmp/spx_eod_201701.txt
# Reading tmp/spx_eod_201711.txt
# Reading tmp/spx_eod_201705.txt
# Reading tmp/spx_eod_201704.txt
# Reading tmp/spx_eod_201710.txt
# Reading tmp/spx_eod_201706.txt
# Reading tmp/spx_eod_201712.txt
# Reading tmp/spx_eod_201707.txt
# Reading tmp/spx_eod_201709.txt
# Reading tmp/spx_eod_201708.txt
# Processing year: 2018
#   ➤ Extracting spx_eod_2018-uqawfl.7z
# Reading tmp/spx_eod_201809.txt
# Reading tmp/spx_eod_201808.txt
# Reading tmp/spx_eod_201812.txt
# Reading tmp/spx_eod_201806.txt
# Reading tmp/spx_eod_201807.txt
# Reading tmp/spx_eod_201805.txt
# Reading tmp/spx_eod_201811.txt
# Reading tmp/spx_eod_201810.txt
# Reading tmp/spx_eod_201804.txt
# Reading tmp/spx_eod_201801.txt
# Reading tmp/spx_eod_201803.txt
# Reading tmp/spx_eod_201802.txt
# Processing year: 2019
#   ➤ Extracting spx_eod_2019-chxexe.7z
# Reading tmp/spx_eod_201909.txt
# Reading tmp/spx_eod_201908.txt
# Reading tmp/spx_eod_201905.txt
# Reading tmp/spx_eod_201911.txt
# Reading tmp/spx_eod_201910.txt
# Reading tmp/spx_eod_201904.txt
# Reading tmp/spx_eod_201912.txt
# Reading tmp/spx_eod_201906.txt
# Reading tmp/spx_eod_201907.txt
# Reading tmp/spx_eod_201903.txt
# Reading tmp/spx_eod_201902.txt
# Reading tmp/spx_eod_201901.txt
# Processing year: 2020
#   ➤ Extracting spx_eod_2020-wh6jt7.7z
# Reading tmp/spx_eod_202008.txt
# Reading tmp/spx_eod_202009.txt
# Reading tmp/spx_eod_202001.txt
# Reading tmp/spx_eod_202002.txt
# Reading tmp/spx_eod_202003.txt
# Reading tmp/spx_eod_202007.txt
# Reading tmp/spx_eod_202012.txt
# Reading tmp/spx_eod_202006.txt
# Reading tmp/spx_eod_202010.txt
# Reading tmp/spx_eod_202004.txt
# Reading tmp/spx_eod_202005.txt
# Reading tmp/spx_eod_202011.txt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 7
#       5 df = load_options(RAW_PATH / option_path, start_year=start_year, end_year=end_year)
#       6 df = clean_data(df)
# ----> 7 df = reshape_options_long_to_wide(df)
#       9 output_file = INTERMEDIATE_PATH / f"full_{option_path}_{start_year}_{end_year}.parquet"
#      10 df.to_parquet(output_file, index=True)
#
# File ~/VSCode/python_project/volatility_trading/utility/data_processor_helpers.py:105, in reshape_options_long_to_wide(df)
#      94 cols_to_include = [
#      95     'date',
#      96     'underlying_last',
#    (...)    101     'strike_distance_pct'
#     102 ]
#     104 non_option_cols = [col for col in df.columns if col in cols_to_include]
# --> 105 wide_df = df.pivot(index=non_option_cols, columns="option_type")
#     106 wide_df.columns = [f"{opt.lower()}_{col.lower()}" for col, opt in wide_df.columns]
#     108 if "date" in non_option_cols:
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/frame.py:9346, in DataFrame.pivot(self, columns, index, values)
#    9339 @Substitution("")
#    9340 @Appender(_shared_docs["pivot"])
#    9341 def pivot(
#    9342     self, *, columns, index=lib.no_default, values=lib.no_default
#    9343 ) -> DataFrame:
#    9344     from pandas.core.reshape.pivot import pivot
# -> 9346     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:570, in pivot(data, columns, index, values)
#     566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     567 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     568 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     569 # "Hashable"
# --> 570 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     571 result.index.names = [
#     572     name if name is not lib.no_default else None for name in result.index.names
#     573 ]
#     575 return result
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/frame.py:9935, in DataFrame.unstack(self, level, fill_value, sort)
#    9871 """
#    9872 Pivot a level of the (necessarily hierarchical) index labels.
#    9873
#    (...)   9931 dtype: float64
#    9932 """
#    9933 from pandas.core.reshape.reshape import unstack
# -> 9935 result = unstack(self, level, fill_value, sort)
#    9937 return result.__finalize__(self, method="unstack")
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:504, in unstack(obj, level, fill_value, sort)
#     502 if isinstance(obj, DataFrame):
#     503     if isinstance(obj.index, MultiIndex):
# --> 504         return _unstack_frame(obj, level, fill_value=fill_value, sort=sort)
#     505     else:
#     506         return obj.T.stack(future_stack=True)
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:529, in _unstack_frame(obj, level, fill_value, sort)
#     525 def _unstack_frame(
#     526     obj: DataFrame, level, fill_value=None, sort: bool = True
#     527 ) -> DataFrame:
#     528     assert isinstance(obj.index, MultiIndex)  # checked by caller
# --> 529     unstacker = _Unstacker(
#     530         obj.index, level=level, constructor=obj._constructor, sort=sort
#     531     )
#     533     if not obj._can_fast_transpose:
#     534         mgr = obj._mgr.unstack(unstacker, fill_value=fill_value)
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:154, in _Unstacker.__init__(self, index, level, constructor, sort)
#     146 if num_cells > np.iinfo(np.int32).max:
#     147     warnings.warn(
#     148         f"The following operation may generate {num_cells} cells "
#     149         f"in the resulting pandas object.",
#     150         PerformanceWarning,
#     151         stacklevel=find_stack_level(),
#     152     )
# --> 154 self._make_selectors()
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:210, in _Unstacker._make_selectors(self)
#     207 mask.put(selector, True)
#     209 if mask.sum() < len(self.index):
# --> 210     raise ValueError("Index contains duplicate entries, cannot reshape")
#     212 self.group_index = comp_index
#     213 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
a = reshape_options_long_to_wide(df.loc["2018"])

# %%
df.loc["2018"]
# Out:
#             underlying_last     expiry     dte  strike  strike_distance  \
# date
# 2018-01-02          2695.87 2018-01-19    17.0   100.0           2595.9
# 2018-01-02          2695.87 2018-06-15   164.0   100.0           2595.9
# 2018-01-02          2695.87 2018-12-21   353.0   100.0           2595.9
# 2018-01-02          2695.87 2019-12-20   717.0   100.0           2595.9
# 2018-01-02          2695.87 2020-12-18  1081.0   100.0           2595.9
# ...                     ...        ...     ...     ...              ...
# 2018-12-31          2506.71 2019-09-20   263.0  4200.0           1693.3
# 2018-12-31          2506.71 2019-09-30   273.0  4200.0           1693.3
# 2018-12-31          2506.71 2019-12-20   354.0  4200.0           1693.3
# 2018-12-31          2506.71 2020-06-19   536.0  4200.0           1693.3
# 2018-12-31          2506.71 2020-12-18   718.0  4200.0           1693.3
#
#             strike_distance_pct  delta  gamma         vega  theta  rho  iv  \
# date
# 2018-01-02                0.963    1.0    0.0      0.00000    0.0  0.0 NaN
# 2018-01-02                0.963    1.0    0.0      0.00000    0.0  0.0 NaN
# 2018-01-02                0.963    1.0    0.0      0.00000    0.0  0.0 NaN
# 2018-01-02                0.963    1.0    0.0      0.00000    0.0  0.0 NaN
# 2018-01-02                0.963    1.0    0.0      0.00000    0.0  0.0 NaN
# ...                         ...    ...    ...          ...    ...  ...  ..
# 2018-12-31                0.675   -1.0    0.0 -16942.89978    0.0  0.0 NaN
# 2018-12-31                0.675   -1.0    0.0 -16942.89992    0.0  0.0 NaN
# 2018-12-31                0.675   -1.0    0.0 -16942.89959    0.0  0.0 NaN
# 2018-12-31                0.675   -1.0    0.0 -16942.89972    0.0  0.0 NaN
# 2018-12-31                0.675   -1.0    0.0 -16942.89963    0.0  0.0 NaN
#
#             volume     last      bid      ask option_type  size_bid  size_ask
# date
# 2018-01-02     0.0     0.00  2589.51  2595.99           C         4         5
# 2018-01-02     0.0     0.00  2569.21  2577.20           C        11        10
# 2018-01-02     0.0     0.00  2540.20  2557.21           C         1         1
# 2018-01-02     1.0  2481.60  2493.50  2510.10           C         2         1
# 2018-01-02     0.0     0.00  2457.90  2466.80           C         1         1
# ...            ...      ...      ...      ...         ...       ...       ...
# 2018-12-31     0.0     0.00  1651.60  1661.90           P       100       100
# 2018-12-31     0.0     0.00  1655.40  1674.20           P         1         1
# 2018-12-31    23.0  1632.00  1634.90  1650.40           P       100       100
# 2018-12-31     0.0     0.00  1604.31  1625.00           P       100        15
# 2018-12-31     2.0  1423.66  1583.30  1598.90           P       150         5
#
# [5529344 rows x 19 columns]

# %%
a = df.loc["2018"]

# %%
a.index.duplicated().sum()
# Out:
# 0

# %%
a
# Out:
#               date  underlying_last     expiry     dte  strike  \
# 0       2018-01-02          2695.87 2018-01-19    17.0   100.0
# 1       2018-01-02          2695.87 2018-06-15   164.0   100.0
# 2       2018-01-02          2695.87 2018-12-21   353.0   100.0
# 3       2018-01-02          2695.87 2019-12-20   717.0   100.0
# 4       2018-01-02          2695.87 2020-12-18  1081.0   100.0
# ...            ...              ...        ...     ...     ...
# 5529339 2018-12-31          2506.71 2019-09-20   263.0  4200.0
# 5529340 2018-12-31          2506.71 2019-09-30   273.0  4200.0
# 5529341 2018-12-31          2506.71 2019-12-20   354.0  4200.0
# 5529342 2018-12-31          2506.71 2020-06-19   536.0  4200.0
# 5529343 2018-12-31          2506.71 2020-12-18   718.0  4200.0
#
#          strike_distance  strike_distance_pct  delta  gamma         vega  \
# 0                 2595.9                0.963    1.0    0.0      0.00000
# 1                 2595.9                0.963    1.0    0.0      0.00000
# 2                 2595.9                0.963    1.0    0.0      0.00000
# 3                 2595.9                0.963    1.0    0.0      0.00000
# 4                 2595.9                0.963    1.0    0.0      0.00000
# ...                  ...                  ...    ...    ...          ...
# 5529339           1693.3                0.675   -1.0    0.0 -16942.89978
# 5529340           1693.3                0.675   -1.0    0.0 -16942.89992
# 5529341           1693.3                0.675   -1.0    0.0 -16942.89959
# 5529342           1693.3                0.675   -1.0    0.0 -16942.89972
# 5529343           1693.3                0.675   -1.0    0.0 -16942.89963
#
#          theta  rho  iv  volume     last      bid      ask option_type  \
# 0          0.0  0.0 NaN     0.0     0.00  2589.51  2595.99           C
# 1          0.0  0.0 NaN     0.0     0.00  2569.21  2577.20           C
# 2          0.0  0.0 NaN     0.0     0.00  2540.20  2557.21           C
# 3          0.0  0.0 NaN     1.0  2481.60  2493.50  2510.10           C
# 4          0.0  0.0 NaN     0.0     0.00  2457.90  2466.80           C
# ...        ...  ...  ..     ...      ...      ...      ...         ...
# 5529339    0.0  0.0 NaN     0.0     0.00  1651.60  1661.90           P
# 5529340    0.0  0.0 NaN     0.0     0.00  1655.40  1674.20           P
# 5529341    0.0  0.0 NaN    23.0  1632.00  1634.90  1650.40           P
# 5529342    0.0  0.0 NaN     0.0     0.00  1604.31  1625.00           P
# 5529343    0.0  0.0 NaN     2.0  1423.66  1583.30  1598.90           P
#
#          size_bid  size_ask
# 0               4         5
# 1              11        10
# 2               1         1
# 3               2         1
# 4               1         1
# ...           ...       ...
# 5529339       100       100
# 5529340         1         1
# 5529341       100       100
# 5529342       100        15
# 5529343       150         5
#
# [5529344 rows x 20 columns]

# %%
a
# Out:
#               date  underlying_last     expiry     dte  strike  \
# 0       2018-01-02          2695.87 2018-01-19    17.0   100.0
# 1       2018-01-02          2695.87 2018-06-15   164.0   100.0
# 2       2018-01-02          2695.87 2018-12-21   353.0   100.0
# 3       2018-01-02          2695.87 2019-12-20   717.0   100.0
# 4       2018-01-02          2695.87 2020-12-18  1081.0   100.0
# ...            ...              ...        ...     ...     ...
# 5529339 2018-12-31          2506.71 2019-09-20   263.0  4200.0
# 5529340 2018-12-31          2506.71 2019-09-30   273.0  4200.0
# 5529341 2018-12-31          2506.71 2019-12-20   354.0  4200.0
# 5529342 2018-12-31          2506.71 2020-06-19   536.0  4200.0
# 5529343 2018-12-31          2506.71 2020-12-18   718.0  4200.0
#
#          strike_distance  strike_distance_pct  delta  gamma         vega  \
# 0                 2595.9                0.963    1.0    0.0      0.00000
# 1                 2595.9                0.963    1.0    0.0      0.00000
# 2                 2595.9                0.963    1.0    0.0      0.00000
# 3                 2595.9                0.963    1.0    0.0      0.00000
# 4                 2595.9                0.963    1.0    0.0      0.00000
# ...                  ...                  ...    ...    ...          ...
# 5529339           1693.3                0.675   -1.0    0.0 -16942.89978
# 5529340           1693.3                0.675   -1.0    0.0 -16942.89992
# 5529341           1693.3                0.675   -1.0    0.0 -16942.89959
# 5529342           1693.3                0.675   -1.0    0.0 -16942.89972
# 5529343           1693.3                0.675   -1.0    0.0 -16942.89963
#
#          theta  rho  iv  volume     last      bid      ask option_type  \
# 0          0.0  0.0 NaN     0.0     0.00  2589.51  2595.99           C
# 1          0.0  0.0 NaN     0.0     0.00  2569.21  2577.20           C
# 2          0.0  0.0 NaN     0.0     0.00  2540.20  2557.21           C
# 3          0.0  0.0 NaN     1.0  2481.60  2493.50  2510.10           C
# 4          0.0  0.0 NaN     0.0     0.00  2457.90  2466.80           C
# ...        ...  ...  ..     ...      ...      ...      ...         ...
# 5529339    0.0  0.0 NaN     0.0     0.00  1651.60  1661.90           P
# 5529340    0.0  0.0 NaN     0.0     0.00  1655.40  1674.20           P
# 5529341    0.0  0.0 NaN    23.0  1632.00  1634.90  1650.40           P
# 5529342    0.0  0.0 NaN     0.0     0.00  1604.31  1625.00           P
# 5529343    0.0  0.0 NaN     2.0  1423.66  1583.30  1598.90           P
#
#          size_bid  size_ask
# 0               4         5
# 1              11        10
# 2               1         1
# 3               2         1
# 4               1         1
# ...           ...       ...
# 5529339       100       100
# 5529340         1         1
# 5529341       100       100
# 5529342       100        15
# 5529343       150         5
#
# [5529344 rows x 20 columns]

# %%
if a.index.name == "date":
    a = a.reset_index()

cols_to_include = [
    'date',
    'underlying_last',
    'expiry',
    'dte',
    'strike',
    'strike_distance',
    'strike_distance_pct'
]

non_option_cols = [col for col in df.columns if col in cols_to_include]
wide_df = a.pivot(index=non_option_cols, columns="option_type")
wide_df.columns = [f"{opt.lower()}_{col.lower()}" for col, opt in wide_df.columns]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 15
#       4 cols_to_include = [
#       5     'date',
#       6     'underlying_last',
#    (...)     11     'strike_distance_pct'
#      12 ]
#      14 non_option_cols = [col for col in df.columns if col in cols_to_include]
# ---> 15 wide_df = a.pivot(index=non_option_cols, columns="option_type")
#      16 wide_df.columns = [f"{opt.lower()}_{col.lower()}" for col, opt in wide_df.columns]
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/frame.py:9346, in DataFrame.pivot(self, columns, index, values)
#    9339 @Substitution("")
#    9340 @Appender(_shared_docs["pivot"])
#    9341 def pivot(
#    9342     self, *, columns, index=lib.no_default, values=lib.no_default
#    9343 ) -> DataFrame:
#    9344     from pandas.core.reshape.pivot import pivot
# -> 9346     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:570, in pivot(data, columns, index, values)
#     566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     567 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     568 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     569 # "Hashable"
# --> 570 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     571 result.index.names = [
#     572     name if name is not lib.no_default else None for name in result.index.names
#     573 ]
#     575 return result
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/frame.py:9935, in DataFrame.unstack(self, level, fill_value, sort)
#    9871 """
#    9872 Pivot a level of the (necessarily hierarchical) index labels.
#    9873
#    (...)   9931 dtype: float64
#    9932 """
#    9933 from pandas.core.reshape.reshape import unstack
# -> 9935 result = unstack(self, level, fill_value, sort)
#    9937 return result.__finalize__(self, method="unstack")
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:504, in unstack(obj, level, fill_value, sort)
#     502 if isinstance(obj, DataFrame):
#     503     if isinstance(obj.index, MultiIndex):
# --> 504         return _unstack_frame(obj, level, fill_value=fill_value, sort=sort)
#     505     else:
#     506         return obj.T.stack(future_stack=True)
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:529, in _unstack_frame(obj, level, fill_value, sort)
#     525 def _unstack_frame(
#     526     obj: DataFrame, level, fill_value=None, sort: bool = True
#     527 ) -> DataFrame:
#     528     assert isinstance(obj.index, MultiIndex)  # checked by caller
# --> 529     unstacker = _Unstacker(
#     530         obj.index, level=level, constructor=obj._constructor, sort=sort
#     531     )
#     533     if not obj._can_fast_transpose:
#     534         mgr = obj._mgr.unstack(unstacker, fill_value=fill_value)
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:154, in _Unstacker.__init__(self, index, level, constructor, sort)
#     146 if num_cells > np.iinfo(np.int32).max:
#     147     warnings.warn(
#     148         f"The following operation may generate {num_cells} cells "
#     149         f"in the resulting pandas object.",
#     150         PerformanceWarning,
#     151         stacklevel=find_stack_level(),
#     152     )
# --> 154 self._make_selectors()
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:210, in _Unstacker._make_selectors(self)
#     207 mask.put(selector, True)
#     209 if mask.sum() < len(self.index):
# --> 210     raise ValueError("Index contains duplicate entries, cannot reshape")
#     212 self.group_index = comp_index
#     213 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape
